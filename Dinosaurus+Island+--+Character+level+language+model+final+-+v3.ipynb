# %% [markdown]
# # Character level language model - Dinosaurus land
#
# Welcome to Dinosaurus Island! 65 million years ago, dinosaurs existed, and in this assignment they are back. You are in charge of a special task. Leading biology researchers are creating new breeds of dinosaurs and bringing them to life on earth, and your job is to give names to these dinosaurs. If a dinosaur does not like its name, it might go beserk, so choose wisely!
#
# <table>
# <td>
# <img src="images/dino.jpg" style="width:250;height:300px;">
#
# </td>
#
# </table>
#
# Luckily you have learned some deep learning and you will use it to save the day. Your assistant has collected a list of all the dinosaur names they could find, and compiled them into this [dataset](dinos.txt). (Feel free to take a look by clicking the previous link.) To create new dinosaur names, you will build a character level language model to generate new names. Your algorithm will learn the different name patterns, and randomly generate new names. Hopefully this algorithm will keep you and your team safe from the dinosaurs' wrath!
#
# By completing this assignment you will learn:
#
# - How to store text data for processing using an RNN
# - How to synthesize data, by sampling predictions at each time step and passing it to the next RNN-cell unit
# - How to build a character-level text generation recurrent neural network
# - Why clipping the gradients is important
#
# We will begin by loading in some functions that we have provided for you in `rnn_utils`. Specifically, you have access to functions such as `rnn_forward` and `rnn_backward` which are equivalent to those you've implemented in the previous assignment.

# %%
import numpy as np
from utils import *
import random

# %% [markdown]
# ## 1 - Problem Statement
#
# ### 1.1 - Dataset and Preprocessing
#
# Run the following cell to read the dataset of dinosaur names, create a list of unique characters (such as a-z), and compute the dataset and vocabulary size.

# %%
data = open('dinos.txt', 'r').read()
data= data.lower()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('There are %d total characters and %d unique characters in your data.' % (data_size, vocab_size))

# %% [markdown]
# The characters are a-z (26 characters) plus the "\n" (or newline character), which in this assignment plays a role similar to the `<EOS>` (or "End of sentence") token we had discussed in lecture, only here it indicates the end of the dinosaur name rather than the end of a sentence. In the cell below, we create a python dictionary (i.e., a hash table) to map each character to an index from 0-26. We also create a second python dictionary that maps each index back to the corresponding character character. This will help you figure out what index corresponds to what character in the probability distribution output of the softmax layer. Below, `char_to_ix` and `ix_to_char` are the python dictionaries.

# %%
char_to_ix = { ch:i for i,ch in enumerate(sorted(chars)) }
ix_to_char = { i:ch for i,ch in enumerate(sorted(chars)) }
print(ix_to_char)

# %% [markdown]
# ### 1.2 - Overview of the model
#
# Your model will have the following structure:
#
# - Initialize parameters
# - Run the optimization loop
#     - Forward propagation to compute the loss function
#     - Backward propagation to compute the gradients with respect to the loss function
#     - Clip the gradients to avoid exploding gradients
#     - Using the gradients, update your parameter with the gradient descent update rule.
# - Return the learned parameters
#
# <img src="images/rnn.png" style="width:450;height:300px;">
# <caption><center> **Figure 1**: Recurrent Neural Network, similar to what you had built in the previous notebook "Building a RNN - Step by Step".  </center></caption>
#
# At each time-step, the RNN tries to predict what is the next character given the previous characters. The dataset $X = (x^{\langle 1 \rangle}, x^{\langle 2 \rangle}, ..., x^{\langle T_x \rangle})$ is a list of characters in the training set, while $Y = (y^{\langle 1 \rangle}, y^{\langle 2 \rangle}, ..., y^{\langle T_x \rangle})$ is such that at every time-step $t$, we have $y^{\langle t \rangle} = x^{\langle t+1 \rangle}$.

# %% [markdown]
# ## 2 - Building blocks of the model
#
# In this part, you will build two important blocks of the overall model:
# - Gradient clipping: to avoid exploding gradients
# - Sampling: a technique used to generate characters
#
# You will then apply these two functions to build the model.

# %% [markdown]
# ### 2.1 - Clipping the gradients in the optimization loop
#
# In this section you will implement the `clip` function that you will call inside of your optimization loop. Recall that your overall loop structure usually consists of a forward pass, a cost computation, a backward pass, and a parameter update. Before updating the parameters, you will perform gradient clipping when needed to make sure that your gradients are not "exploding," meaning taking on overly large values.
#
# In the exercise below, you will implement a function `clip` that takes in a dictionary of gradients and returns a clipped version of gradients if needed. There are different ways to clip gradients; we will use a simple element-wise clipping procedure, in which every element of the gradient vector is clipped to lie between some range [-N, N]. More generally, you will provide a `maxValue` (say 10). In this example, if any component of the gradient vector is greater than 10, it would be set to 10; and if any component of the gradient vector is less than -10, it would be set to -10. If it is between -10 and 10, it is left alone.
#
# <img src="images/clip.png" style="width:400;height:150px;">
# <caption><center> **Figure 2**: Visualization of gradient descent with and without gradient clipping, in a case where the network is running into slight "exploding gradient" problems. </center></caption>
#
# **Exercise**: Implement the function below to return the clipped gradients of your dictionary `gradients`. Your function takes in a maximum threshold and returns the clipped versions of your gradients. You can check out this [hint](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.clip.html) for examples of how to clip in numpy. You will need to use the argument `out = ...`.

# %%
### GRADED FUNCTION: clip

def clip(gradients, maxValue):
    '''
    Clips the gradients' values between minimum and maximum.
    
    Arguments:
    gradients -- a dictionary containing the gradients "dWaa", "dWax", "dWya", "db", "dby"
    maxValue -- everything above this number is set to this number, and everything less than -maxValue is set to -maxValue
    
    Returns: 
    gradients -- a dictionary with the clipped gradients.
    '''
    
    dWaa, dWax, dWya, db, dby = gradients['dWaa'], gradients['dWax'], gradients['dWya'], gradients['db'], gradients['dby']
   
    ### START CODE HERE ###
    # clip to mitigate exploding gradients, loop over [dWax, dWaa, dWya, db, dby]. (≈2 lines)
    for gradient in gradients:
        gradients[gradient] = np.clip(gradients[gradient], a_min=-maxValue, a_max=maxValue)
    dWaa, dWax, dWya, db, dby = gradients['dWaa'], gradients['dWax'], gradients['dWya'], gradients['db'], gradients['dby']
        ### END CODE HERE ###
    
    gradients = {"dWaa": dWaa, "dWax": dWax, "dWya": dWya, "db": db, "dby": dby}
    
    return gradients

# %%
np.random.seed(3)
dWax = np.random.randn(5,3)*10
dWaa = np.random.randn(5,5)*10
dWya = np.random.randn(2,5)*10
db = np.random.randn(5,1)*10
dby = np.random.randn(2,1)*10
gradients = {"dWax": dWax, "dWaa": dWaa, "dWya": dWya, "db": db, "dby": dby}
gradients = clip(gradients, 10)
print("gradients[\"dWaa\"][1][2] =", gradients["dWaa"][1][2])
print("gradients[\"dWax\"][3][1] =", gradients["dWax"][3][1])
print("gradients[\"dWya\"][1][2] =", gradients["dWya"][1][2])
print("gradients[\"db\"][4] =", gradients["db"][4])
print("gradients[\"dby\"][1] =", gradients["dby"][1])

# %% [markdown]
# ** Expected output:**
#
# <table>
# <tr>
#     <td>
#     **gradients["dWaa"][1][2] **
#     </td>
#     <td>
#     10.0
#     </td>
# </tr>
#
# <tr>
#     <td>
#     **gradients["dWax"][3][1]**
#     </td>
#     <td>
#     -10.0
#     </td>
#     </td>
# </tr>
# <tr>
#     <td>
#     **gradients["dWya"][1][2]**
#     </td>
#     <td>
# 0.29713815361
#     </td>
# </tr>
# <tr>
#     <td>
#     **gradients["db"][4]**
#     </td>
#     <td>
# [ 10.]
#     </td>
# </tr>
# <tr>
#     <td>
#     **gradients["dby"][1]**
#     </td>
#     <td>
# [ 8.45833407]
#     </td>
# </tr>
#
# </table>

# %% [markdown]
# ### 2.2 - Sampling
#
# Now assume that your model is trained. You would like to generate new text (characters). The process of generation is explained in the picture below:
#
# <img src="images/dinos3.png" style="width:500;height:300px;">
# <caption><center> **Figure 3**: In this picture, we assume the model is already trained. We pass in $x^{\langle 1\rangle} = \vec{0}$ at the first time step, and have the network then sample one character at a time. </center></caption>
#
# **Exercise**: Implement the `sample` function below to sample characters. You need to carry out 4 steps:
#
# - **Step 1**: Pass the network the first "dummy" input $x^{\langle 1 \rangle} = \vec{0}$ (the vector of zeros). This is the default input before we've generated any characters. We also set $a^{\langle 0 \rangle} = \vec{0}$
#
# - **Step 2**: Run one step of forward propagation to get $a^{\langle 1 \rangle}$ and $\hat{y}^{\langle 1 \rangle}$. Here are the equations:
#
# $$ a^{\langle t+1 \rangle} = \tanh(W_{ax}  x^{\langle t \rangle } + W_{aa} a^{\langle t \rangle } + b)\tag{1}$$
#
# $$ z^{\langle t + 1 \rangle } = W_{ya}  a^{\langle t + 1 \rangle } + b_y \tag{2}$$
#
# $$ \hat{y}^{\langle t+1 \rangle } = softmax(z^{\langle t + 1 \rangle })\tag{3}$$
#
# Note that $\hat{y}^{\langle t+1 \rangle }$ is a (softmax) probability vector (its entries are between 0 and 1 and sum to 1). $\hat{y}^{\langle t+1 \rangle}_i$ represents the probability that the character indexed by "i" is the next character.  We have provided a `softmax()` function that you can use.
#
# - **Step 3**: Carry out sampling: Pick the next character's index according to the probability distribution specified by $\hat{y}^{\langle t+1 \rangle }$. This means that if $\hat{y}^{\langle t+1 \rangle }_i = 0.16$, you will pick the index "i" with 16% probability. To implement it, you can use [`np.random.choice`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.random.choice.html).
#
# Here is an example of how to use `np.random.choice()`:
# ```python
# np.random.seed(0)
# p = np.array([0.1, 0.0, 0.7, 0.2])
# index = np.random.choice([0, 1, 2, 3], p = p.ravel())
# ```
# This means that you will pick the `index` according to the distribution:
# $P(index = 0) = 0.1, P(index = 1) = 0.0, P(index = 2) = 0.7, P(index = 3) = 0.2$.
#
# - **Step 4**: The last step to implement in `sample()` is to overwrite the variable `x`, which currently stores $x^{\langle t \rangle }$, with the value of $x^{\langle t + 1 \rangle }$. You will represent $x^{\langle t + 1 \rangle }$ by creating a one-hot vector corresponding to the character you've chosen as your prediction. You will then forward propagate $x^{\langle t + 1 \rangle }$ in Step 1 and keep repeating the process until you get a "\n" character, indicating you've reached the end of the dinosaur name.

# %%
# GRADED FUNCTION: sample

def sample(parameters, char_to_ix, seed):
    """
    Sample a sequence of characters according to a sequence of probability distributions output of the RNN

    Arguments:
    parameters -- python dictionary containing the parameters Waa, Wax, Wya, by, and b. 
    char_to_ix -- python dictionary mapping each character to an index.
    seed -- used for grading purposes. Do not worry about it.

    Returns:
    indices -- a list of length n containing the indices of the sampled characters.
    """
    
    # Retrieve parameters and relevant shapes from "parameters" dictionary
    Waa, Wax, Wya, by, b = parameters['Waa'], parameters['Wax'], parameters['Wya'], parameters['by'], parameters['b']
    vocab_size = by.shape[0]
    n_a = Waa.shape[1]
    n_x = Wax.shape[1]
    
    ### START CODE HERE ###
    # Step 1: Create the one-hot vector x for the first character (initializing the sequence generation). (≈1 line)
    x = np.zeros((n_x, 1))
    # Step 1': Initialize a_prev as zeros (≈1 line)
    a_prev = np.zeros((n_a, 1))
    
    # Create an empty list of indices, this is the list which will contain the list of indices of the characters to generate (≈1 line)
    indices = []
    
    # Idx is a flag to detect a newline character, we initialize it to -1
    idx = -1 
    
    # Loop over time-steps t. At each time-step, sample a character from a probability distribution and append 
    # its index to "indices". We'll stop if we reach 50 characters (which should be very unlikely with a well 
    # trained model), which helps debugging and prevents entering an infinite loop. 
    counter = 0
    newline_character = char_to_ix['\n']
    
    while (idx != newline_character and counter != 50):
        
        # Step 2: Forward propagate x using the equations (1), (2) and (3)
        a = a_prev
        z = np.tanh(np.dot(Waa, a) + np.dot(Wax, x) + b)
        y = softmax(np.dot(Wya, z) + by)
        
        # for grading purposes
        np.random.seed(counter+seed) 
        
        # Step 3: Sample the index of a character within the vocabulary from the probability distribution y
        idx = np.random.choice(range(0, vocab_size), p = y.ravel())
        # Append the index to "indices"
        indices.append(idx)
        
        # Step 4: Overwrite the input character as the one corresponding to the sampled index.
        x = np.zeros((n_x, 1))
        x[idx] = 1
        
        # Update "a_prev" to be "a"
        a_prev = z
        
        # for grading purposes
        seed += 1
        counter +=1
        
    ### END CODE HERE ###

    if (counter == 50):
        indices.append(char_to_ix['\n'])
    
    return indices

# %%
np.random.seed(2)
_, n_a = 20, 100
Wax, Waa, Wya = np.random.randn(n_a, vocab_size), np.random.randn(n_a, n_a), np.random.randn(vocab_size, n_a)
b, by = np.random.randn(n_a, 1), np.random.randn(vocab_size, 1)
parameters = {"Wax": Wax, "Waa": Waa, "Wya": Wya, "b": b, "by": by}


indices = sample(parameters, char_to_ix, 0)
print("Sampling:")
print("list of sampled indices:", indices)
print("list of sampled characters:", [ix_to_char[i] for i in indices])

# %% [markdown]
# ** Expected output:**
# <table>
# <tr>
#     <td>
#     **list of sampled indices:**
#     </td>
#     <td>
#     [12, 17, 24, 14, 13, 9, 10, 22, 24, 6, 13, 11, 12, 6, 21, 15, 21, 14, 3, 2, 1, 21, 18, 24, <br>
#     7, 25, 6, 25, 18, 10, 16, 2, 3, 8, 15, 12, 11, 7, 1, 12, 10, 2, 7, 7, 11, 5, 6, 12, 25, 0, 0]
#     </td>
#     </tr><tr>
#     <td>
#     **list of sampled characters:**
#     </td>
#     <td>
#     ['l', 'q', 'x', 'n', 'm', 'i', 'j', 'v', 'x', 'f', 'm', 'k', 'l', 'f', 'u', 'o', <br>
#     'u', 'n', 'c', 'b', 'a', 'u', 'r', 'x', 'g', 'y', 'f', 'y', 'r', 'j', 'p', 'b', 'c', 'h', 'o', <br>
#     'l', 'k', 'g', 'a', 'l', 'j', 'b', 'g', 'g', 'k', 'e', 'f', 'l', 'y', '\n', '\n']
#     </td>
#
#
#
# </tr>
# </table>

# %% [markdown]
# ## 3 - Building the language model
#
# It is time to build the character-level language model for text generation.
#
#
# ### 3.1 - Gradient descent
#
# In this section you will implement a function performing one step of stochastic gradient descent (with clipped gradients). You will go through the training examples one at a time, so the optimization algorithm will be stochastic gradient descent. As a reminder, here are the steps of a common optimization loop for an RNN:
#
# - Forward propagate through the RNN to compute the loss
# - Backward propagate through time to compute the gradients of the loss with respect to the parameters
# - Clip the gradients if necessary
# - Update your parameters using gradient descent
#
# **Exercise**: Implement this optimization process (one step of stochastic gradient descent).
#
# We provide you with the following functions:
#
# ```python
# def rnn_forward(X, Y, a_prev, parameters):
#     """ Performs the forward propagation through the RNN and computes the cross-entropy loss.
#     It returns the loss' value as well as a "cache" storing values to be used in the backpropagation."""
#     ....
#     return loss, cache
#
# def rnn_backward(X, Y, parameters, cache):
#     """ Performs the backward propagation through time to compute the gradients of the loss with respect
#     to the parameters. It returns also all the hidden states."""
#     ...
#     return gradients, a
#
# def update_parameters(parameters, gradients, learning_rate):
#     """ Updates parameters using the Gradient Descent Update Rule."""
#     ...
#     return parameters
# ```

# %%
# GRADED FUNCTION: optimize

def optimize(X, Y, a_prev, parameters, learning_rate = 0.01):
    """
    Execute one step of the optimization to train the model.
    
    Arguments:
    X -- list of integers, where each integer is a number that maps to a character in the vocabulary.
    Y -- list of integers, exactly the same as X but shifted one index to the left.
    a_prev -- previous hidden state.
    parameters -- python dictionary containing:
                        Wax -- Weight matrix multiplying the input, numpy array of shape (n_a, n_x)
                        Waa -- Weight matrix multiplying the hidden state, numpy array of shape (n_a, n_a)
                        Wya -- Weight matrix relating the hidden-state to the output, numpy array of shape (n_y, n_a)
                        b --  Bias, numpy array of shape (n_a, 1)
                        by -- Bias relating the hidden-state to the output, numpy array of shape (n_y, 1)
    learning_rate -- learning rate for the model.
    
    Returns:
    loss -- value of the loss function (cross-entropy)
    gradients -- python dictionary containing:
                        dWax -- Gradients of input-to-hidden weights, of shape (n_a, n_x)
                        dWaa -- Gradients of hidden-to-hidden weights, of shape (n_a, n_a)
                        dWya -- Gradients of hidden-to-output weights, of shape (n_y, n_a)
                        db -- Gradients of bias vector, of shape (n_a, 1)
                        dby -- Gradients of output bias vector, of shape (n_y, 1)
    a[len(X)-1] -- the last hidden state, of shape (n_a, 1)
    """
    
    ### START CODE HERE ###
    
    # Forward propagate through time (≈1 line)
    loss, cache = rnn_forward(X, Y, a_prev, parameters)
    
    # Backpropagate through time (≈1 line)
    gradients, a = rnn_backward(X, Y, parameters, cache)
    
    # Clip your gradients between -5 (min) and 5 (max) (≈1 line)
    gradients = clip(gradients, 5.0)
    
    # Update parameters (≈1 line)
    parameters = update_parameters(parameters, gradients, learning_rate)
    
    ### END CODE HERE ###
    
    return loss, gradients, a[len(X)-1]

# %%
np.random.seed(1)
vocab_size, n_a = 27, 100
a_prev = np.random.randn(n_a, 1)
Wax, Waa, Wya = np.random.randn(n_a, vocab_size), np.random.randn(n_a, n_a), np.random.randn(vocab_size, n_a)
b, by = np.random.randn(n_a, 1), np.random.randn(vocab_size, 1)
parameters = {"Wax": Wax, "Waa": Waa, "Wya": Wya, "b": b, "by": by}
X = [12,3,5,11,22,3]
Y = [4,14,11,22,25, 26]

loss, gradients, a_last = optimize(X, Y, a_prev, parameters, learning_rate = 0.01)
print("Loss =", loss)
print("gradients[\"dWaa\"][1][2] =", gradients["dWaa"][1][2])
print("np.argmax(gradients[\"dWax\"]) =", np.argmax(gradients["dWax"]))
print("gradients[\"dWya\"][1][2] =", gradients["dWya"][1][2])
print("gradients[\"db\"][4] =", gradients["db"][4])
print("gradients[\"dby\"][1] =", gradients["dby"][1])
print("a_last[4] =", a_last[4])

# %% [markdown]
# ** Expected output:**
#
# <table>
#
#
# <tr>
#     <td>
#     **Loss **
#     </td>
#     <td>
#     126.503975722
#     </td>
# </tr>
# <tr>
#     <td>
#     **gradients["dWaa"][1][2]**
#     </td>
#     <td>
#     0.194709315347
#     </td>
# <tr>
#     <td>
#     **np.argmax(gradients["dWax"])**
#     </td>
#     <td> 93
#     </td>
# </tr>
# <tr>
#     <td>
#     **gradients["dWya"][1][2]**
#     </td>
#     <td> -0.007773876032
#     </td>
# </tr>
# <tr>
#     <td>
#     **gradients["db"][4]**
#     </td>
#     <td> [-0.06809825]
#     </td>
# </tr>
# <tr>
#     <td>
#     **gradients["dby"][1]**
#     </td>
#     <td>[ 0.01538192]
#     </td>
# </tr>
# <tr>
#     <td>
#     **a_last[4]**
#     </td>
#     <td> [-1.]
#     </td>
# </tr>
#
# </table>

# %% [markdown]
# ### 3.2 - Training the model

# %% [markdown]
# Given the dataset of dinosaur names, we use each line of the dataset (one name) as one training example. Every 100 steps of stochastic gradient descent, you will sample 10 randomly chosen names to see how the algorithm is doing. Remember to shuffle the dataset, so that stochastic gradient descent visits the examples in random order.
#
# **Exercise**: Follow the instructions and implement `model()`. When `examples[index]` contains one dinosaur name (string), to create an example (X, Y), you can use this:
# ```python
#         index = j % len(examples)
#         X = [None] + [char_to_ix[ch] for ch in examples[index]]
#         Y = X[1:] + [char_to_ix["\n"]]
# ```
# Note that we use: `index= j % len(examples)`, where `j = 1....num_iterations`, to make sure that `examples[index]` is always a valid statement (`index` is smaller than `len(examples)`).
# The first entry of `X` being `None` will be interpreted by `rnn_forward()` as setting $x^{\langle 0 \rangle} = \vec{0}$. Further, this ensures that `Y` is equal to `X` but shifted one step to the left, and with an additional "\n" appended to signify the end of the dinosaur name.

# %%
# GRADED FUNCTION: model

def model(data, ix_to_char, char_to_ix, num_iterations = 35000, n_a = 50, dino_names = 7, vocab_size = 27):
    """
    Trains the model and generates dinosaur names. 
    
    Arguments:
    data -- text corpus
    ix_to_char -- dictionary that maps the index to a character
    char_to_ix -- dictionary that maps a character to an index
    num_iterations -- number of iterations to train the model for
    n_a -- number of units of the RNN cell
    dino_names -- number of dinosaur names you want to sample at each iteration. 
    vocab_size -- number of unique characters found in the text, size of the vocabulary
    
    Returns:
    parameters -- learned parameters
    """
    
    # Retrieve n_x and n_y from vocab_size
    n_x, n_y = vocab_size, vocab_size
    
    # Initialize parameters
    parameters = initialize_parameters(n_a, n_x, n_y)
    
    # Initialize loss (this is required because we want to smooth our loss, don't worry about it)
    loss = get_initial_loss(vocab_size, dino_names)
    
    # Build list of all dinosaur names (training examples).
    with open("dinos.txt") as f:
        examples = f.readlines()
    examples = [x.lower().strip() for x in examples]
    
    # Shuffle list of all dinosaur names
    np.random.seed(0)
    np.random.shuffle(examples)
    
    # Initialize the hidden state of your LSTM
    a_prev = np.zeros((n_a, 1))
    
    # Optimization loop
    for j in range(num_iterations):
        
        ### START CODE HERE ###
        
        # Use the hint above to define one training example (X,Y) (≈ 2 lines)
        index = j % len(examples)
        X = [None] + [char_to_ix[ch] for ch in examples[index]] 
        Y = X[1:] + [char_to_ix["\n"]]
        
        # Perform one optimization step: Forward-prop -> Backward-prop -> Clip -> Update parameters
        # Choose a learning rate of 0.01
        curr_loss, gradients, a_prev = optimize(X, Y, a_prev, parameters, learning_rate = 0.01)
        
        ### END CODE HERE ###
        
        # Use a latency trick to keep the loss smooth. It happens here to accelerate the training.
        loss = smooth(loss, curr_loss)

        # Every 2000 Iteration, generate "n" characters thanks to sample() to check if the model is learning properly
        if j % 2000 == 0:
            
            print('Iteration: %d, Loss: %f' % (j, loss) + '\n')
            
            # The number of dinosaur names to print
            seed = 0
            for name in range(dino_names):
                
                # Sample indices and print them
                sampled_indices = sample(parameters, char_to_ix, seed)
                print_sample(sampled_indices, ix_to_char)
                
                seed += 1  # To get the same result for grading purposed, increment the seed by one. 
      
            print('\n')
        
    return parameters

# %% [markdown]
# Run the following cell, you should observe your model outputting random-looking characters at the first iteration. After a few thousand iterations, your model should learn to generate reasonable-looking names.

# %%
parameters = model(data, ix_to_char, char_to_ix)

# %% [markdown]
# ## Conclusion
#
# You can see that your algorithm has started to generate plausible dinosaur names towards the end of the training. At first, it was generating random characters, but towards the end you could see dinosaur names with cool endings. Feel free to run the algorithm even longer and play with hyperparameters to see if you can get even better results. Our implemetation generated some really cool names like `maconucon`, `marloralus` and `macingsersaurus`. Your model hopefully also learned that dinosaur names tend to end in `saurus`, `don`, `aura`, `tor`, etc.
#
# If your model generates some non-cool names, don't blame the model entirely--not all actual dinosaur names sound cool. (For example, `dromaeosauroides` is an actual dinosaur name and is in the training set.) But this model should give you a set of candidates from which you can pick the coolest!
#
# This assignment had used a relatively small dataset, so that you could train an RNN quickly on a CPU. Training a model of the english language requires a much bigger dataset, and usually needs much more computation, and could run for many hours on GPUs. We ran our dinosaur name for quite some time, and so far our favoriate name is the great, undefeatable, and fierce: Mangosaurus!
#
# <img src="images/mangosaurus.jpeg" style="width:250;height:300px;">

# %% [markdown]
# ## 4 - Writing like Shakespeare
#
# The rest of this notebook is optional and is not graded, but we hope you'll do it anyway since it's quite fun and informative.
#
# A similar (but more complicated) task is to generate Shakespeare poems. Instead of learning from a dataset of Dinosaur names you can use a collection of Shakespearian poems. Using LSTM cells, you can learn longer term dependencies that span many characters in the text--e.g., where a character appearing somewhere a sequence can influence what should be a different character much much later in ths sequence. These long term dependencies were less important with dinosaur names, since the names were quite short.
#
#
# <img src="images/shakespeare.jpg" style="width:500;height:400px;">
# <caption><center> Let's become poets! </center></caption>
#
# We have implemented a Shakespeare poem generator with Keras. Run the following cell to load the required packages and models. This may take a few minutes.

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Model, load_model, Sequential
from keras.layers import Dense, Activation, Dropout, Input, Masking
from keras.layers import LSTM
from keras.utils.data_utils import get_file
from keras.preprocessing.sequence import pad_sequences
from shakespeare_utils import *
import sys
import io

# %% [markdown]
# To save you some time, we have already trained a model for ~1000 epochs on a collection of Shakespearian poems called [*"The Sonnets"*](shakespeare.txt).

# %% [markdown]
# Let's train the model for one more epoch. When it finishes training for an epoch---this will also take a few minutes---you can run `generate_output`, which will prompt asking you for an input (`<`40 characters). The poem will start with your sentence, and our RNN-Shakespeare will complete the rest of the poem for you! For example, try "Forsooth this maketh no sense " (don't enter the quotation marks). Depending on whether you include the space at the end, your results might also differ--try it both ways, and try other inputs as well.

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y, batch_size=128, epochs=1, callbacks=[print_callback])

# %%
x.shape, y.shape

# %%
# Run this cell to try with different inputs without having to re-train the model 
generate_output()

# %%
model.predict(x)

# %% [markdown]
# The RNN-Shakespeare model is very similar to the one you have built for dinosaur names. The only major differences are:
# - LSTMs instead of the basic RNN to capture longer-range dependencies
# - The model is a deeper, stacked LSTM model (2 layer)
# - Using Keras instead of python to simplify the code
#
# If you want to learn more, you can also check out the Keras Team's text generation implementation on GitHub: https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py.
#
# Congratulations on finishing this notebook!

# %% [markdown]
# **References**:
# - This exercise took inspiration from Andrej Karpathy's implementation: https://gist.github.com/karpathy/d4dee566867f8291f086. To learn more about text generation, also check out Karpathy's [blog post](http://karpathy.github.io/2015/05/21/rnn-effectiveness/).
# - For the Shakespearian poem generator, our implementation was based on the implementation of an LSTM text generator by the Keras team: https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Model, load_model, Sequential
from keras.layers import Dense, Activation, Dropout, Input, Masking
from keras.layers import LSTM
from keras.utils.data_utils import get_file
from keras.preprocessing.sequence import pad_sequences
from textgen import *
import sys
import io
# Out:
# Using TensorFlow backend.
# Loading text data...
# corpus length: 67869
# total chars: 58
# nb sequences: 22610
# Vectorization...
# Build model...
# WARNING: Logging before flag parsing goes to stderr.
# W0303 12:42:41.809789 46832 deprecation_wrapper.py:119] From C:\Users\Rajath\Anaconda3\envs\nlp_course\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Epoch 1/60
# 22610/22610 [==============================] - 23s 1ms/step - loss: 2.6663
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " on your lips, my bum is on your lips"
# a"
#  on your lips, my bum is on your lips"
# and i' the bit the the the the that in the butt the the the but the thet in the the the the the the the the that me the the the thith thathin't in the the thathe shat in the the bith the the the the the the whot in the the the shot the whe the the the thath the the but the the the thith me the bith the that i the with the thith whe the the the the the the the the the butt i' the the the the the the
# ----- diversity: 0.5
# ----- Generating with seed: " on your lips, my bum is on your lips"
# a"
#  on your lips, my bum is on your lips"
# an't or thit a the thet in a watt i want rot't the shat't an thathe mo it ine the wack butcaup the the yours i't mothe the but in thithin'th the that the buad you thith thet ao the bit't whe the shot and hith with your an't in the whot i mack watt and hith thatithe buthe the the mithe the mathe the thithe sin the thit the butt watt the bith you duth wo i gut thith so thatt the the the thot the the
# ----- diversity: 1.0
# ----- Generating with seed: " on your lips, my bum is on your lips"
# a"
#  on your lips, my bum is on your lips"
# ache an ae rumt mittis, aack'nr upnt it hin thathank root your't myy bitk hoed keon thain' suled juskasl youry, dothi bi't buth rove funk (hirchon't get dvanth it caut youh car oim thithd shinc out inithr arof shitk ren, (ry hwith think put’ aikelit-i, lart thatc
# sileryoran't ann datha mass juttdelrpsinnbut awin' bite bon'th lenst bet hitg so catang the ?ig'th titthit, to to ve sond bit
# i mankingim
# ----- diversity: 1.2
# ----- Generating with seed: " on your lips, my bum is on your lips"
# a"
#  on your lips, my bum is on your lips"
# ap a
# gehy thvyuniten it saneb, kaeay frok1 thon(wrep hasther ckeek ofe wouckys, sahestin' ai'c 'thaywuw wattt
# a to coteyfull se tacs
# ren
# tee detthe soot toom she a me th then thithat rott i  i ovess dit't tif ingmiphein's?
# igwrut's in whath'th
#
# hi fuin' fuat me chutt whin't lit motged l2ecll nat'c
# wod ango cume say catg- wiscis i't thatcoun' juth tu dotch?owile teem non'bb thitht yourulow
# a'tdvopsi
# Epoch 2/60
# 22610/22610 [==============================] - 23s 1ms/step - loss: 2.1164
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "king of the motherfuckin' west coast
# bab"
# king of the motherfuckin' west coast
# bablin' the beck i me the bers i wrow the beck the bers i me the becken i got the seme the bert the beck the ren i got the bers and bither i the bith me the beck me the beck and the bers shit shat me the beckin' the ber and shit shin' ber i men the back and the bet a don't like you den't get the bers i men the me the beck the bers i me the bers i men a some i don't the some shit shamy that shit some
# ----- diversity: 0.5
# ----- Generating with seed: "king of the motherfuckin' west coast
# bab"
# king of the motherfuckin' west coast
# babin' thes i won't bemle the real a this some i don't gin' a gut you dech i got the with shat come the bay shat she be be the bear a don' thay the bey the that som the bere the boun she and thin's i wand up scause shan's the bit me the whers shit a den't gon't les buckin' back thin' a some some come the bens the beck his shat the bick me tome thas that me gove like the been the real you like the bev
# ----- diversity: 1.0
# ----- Generating with seed: "king of the motherfuckin' west coast
# bab"
# king of the motherfuckin' west coast
# bablin' ceat to givy the recai ymu
# it tonet anip whow they rae 'mause you stay focald, cidin' a dre the beeyy bunk thothan lorut, it tomen you dee!, ligin'd bes mithes lor it coll me hiscs it put i h ay all !fs
# 'nm, nome i forens i rennn i's i calin dyourtoliin enprilike hinke (you merip i meaf i madid gun act 'tous is kloa ane thet bays on't your giy thes then wyor pleis dove wanh a notelll
# scaless
# ----- diversity: 1.2
# ----- Generating with seed: "king of the motherfuckin' west coast
# bab"
# king of the motherfuckin' west coast
# babis s?uh! simea notint just gorbe cupco t?ont, froten' gwn the ovop!
# 'em you towy pryup you
# ron't goyou’e, dends i and digho -rowdey the nor wnogl rip, ber hor i tris de?!
# awnon deip bave?
# stanc
# premeer blepice fully fams borsin woth shit mve trldy, stand pher daehed ceet
# uve anvabit no
# non whop, mens
# syub revih
# drome atte! atsive backin
# keth hy mepel, ren'ar backin' your but hedabbwox gon't gecore
# Epoch 3/60
# 22610/22610 [==============================] - 24s 1ms/step - loss: 1.8911
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "and sweeter than bake sales
# reckless, co"
# and sweeter than bake sales
# reckless, come the sand up on the stand up and the stand up you don't got a cont me to stand up and of me the stand up and and and and and and in me the stand up and the stand up and the send and with me the send and in me to slim shady all you con't the be the stand up and and and the seed and and and and wanna got a cont me to stand up and the back and and the seed and and and want of you don't and you con'
# ----- diversity: 0.5
# ----- Generating with seed: "and sweeter than bake sales
# reckless, co"
# and sweeter than bake sales
# reckless, cond me in me the stolt le the stolt lettis of me
# no mon't and that slim shaty the se as up to get he ne the be to stand it has my think and call me manin' me in man shat the plass this wan thay shot to me
# that shit you got the bad and put statin' back my hast stand up and of you to the stont dong at you got a cont me the send up of me think and the be like an mofing of the gans of you'll of this wh
# ----- diversity: 1.0
# ----- Generating with seed: "and sweeter than bake sales
# reckless, co"
# and sweeter than bake sales
# reckless, cond ut sonet this datnall aightres kispie from so tones got an up, we wes aqhy
# whould leasedy pup shamfs th you't on he peas puh smad ag me the me, lit leat your pinter chater dom
# and wesh
# lisem thay and fat it ain yoa realing of me uppphinias and ond
#  of i cun to call guttens, alome bo gotser justad at thre sees ue if ho betse nont as
# a hoof of this bey dird up panctyex to bes domet you crnine up
# ----- diversity: 1.2
# ----- Generating with seed: "and sweeter than bake sales
# reckless, co"
# and sweeter than bake sales
# reckless, come tha hdrmasing no dold to dos's in bo chrtsapons and is i shit
# yon he ancticht, you
# celd-duck corse ctid pup uch in than, i'm s
# a dysog
# wess in
# no won, 'pret
# will i thrord me mid ucl doin monfeps thad we honigh, ene?pdiclrud" on you shovin-just
# to evrone
# sho-the give in aghing in tondat betcond, me indrn
# i'm a can't sll
# on us andren
# thwt sen in
# me feedy battroust, cockert
# came e*tten (wasl!
# (owl
# Epoch 4/60
# 22610/22610 [==============================] - 24s 1ms/step - loss: 1.7087
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "g
# x to the z
# nate dogg
# come on, yeah
#
# aw"
# g
# x to the z
# nate dogg
# come on, yeah
#
# aw you don't got a lot the stand and the really got the strott a crally stand up and wan the from i'm and in the fuckin' the mally get and stand up and the stand up and and and and and the back wat the stand up in the fackin' the stand up and a don't the back me stand up and a dound the back who send and and the mallin' the back who she mather that i say and please stand up and want and and and want
# ----- diversity: 0.5
# ----- Generating with seed: "g
# x to the z
# nate dogg
# come on, yeah
#
# aw"
# g
# x to the z
# nate dogg
# come on, yeah
#
# aw your got a get it's frimt the ther get and i'm a crimede stand up and fuckers the pack with the back me stat the reck it the pleess the strote, i'm a cramin' of your and i'm a cramin' it the and of the nost carced of me mould who some and and back the collite manced and beaned back world wat the stit, you den't i'm and and the ray and not i don't you lattin' the offrem some of the nould back
# whew
# ----- diversity: 1.0
# ----- Generating with seed: "g
# x to the z
# nate dogg
# come on, yeah
#
# aw"
# g
# x to the z
# nate dogg
# come on, yeah
#
# aw the ack bitch of bucyer knew i be?
# i hi'tl i'm rrad of a be thy and slenc at they carly if you wantis boblutnepe to bee the comcknd dight don't stark it they corlin', knew i's know act to hmale i prool as ear eving? my paphen the halls geve beally
# (hit ille-stam shativ
# mer i'm elit mi, stup in’t an't hat, you do everynoal of your
# and to selfa me?
# go bay, your lould in anco’d me, fuck wher put yea
# ----- diversity: 1.2
# ----- Generating with seed: "g
# x to the z
# nate dogg
# come on, yeah
#
# aw"
# g
# x to the z
# nate dogg
# come on, yeah
#
# aw your to lilli'l stats tifahes is realis like frout yeald mo sibae i'm fun the, wwe? of the narear
# i'gle rendy, shott nive in ever your oom youll got thay slitt backesan your fick lot, you led,ase
# some han, cered (i'm s'nach iom plep world the hatnot your
# agjwand oltyy fucks yours, annavesy disti eversed?(backest-i'd the flucks am and ig of knew i'll fon a wasotted 'cause ore sictyloot han the in
# Epoch 5/60
# 22610/22610 [==============================] - 24s 1ms/step - loss: 1.5526
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " knew?
# (i never knew i) who would've kno"
#  knew?
# (i never knew i) who would've know i son't get me walk
# i'm somedy wanna never on the night out a but i just dide stand up and warn the read me the beround me the bick me shit shit dean i just dide stand up on the read
# i just didn't stind i just dide stand up me
# the beround in the berss the beroube she me?
# no the beround me the beroud and get him i just dide stadd up or the beroud no mers the fuckin' the bers and i all the strette
# ----- diversity: 0.5
# ----- Generating with seed: " knew?
# (i never knew i) who would've kno"
#  knew?
# (i never knew i) who would've know i the first, in at the stopt mes it and but i just do dome and inde coreckin' the beroud a love me fuckin' the firss a sromp
# and world the realps do the bick an a cal
# some hord
# who dook wher walkin' the beed worle
# the meanin' the backed and to the back
# the been me and wall the send a like me world of my callin' this dert will a must wers and and with me and me
# (he's)
# i'm back)
# i'm back)
# i'm back
# ----- diversity: 1.0
# ----- Generating with seed: " knew?
# (i never knew i) who would've kno"
#  knew?
# (i never knew i) who would've know doupkin' that whery samps in you allawem, think schear i just chirs!) all with up gange
# shoot to, nots xke, i'm ready an the tirest me, thot on my cale!
# i'm back)
# a may i swrewhin' proploud of whot, a topric
# srer?", i'm so him worll the and him)
# salde, ha branch i'm saimina
# sestins
# not world you like me woll
#
# i'm beck)
# you crewoind of you
#  me cropp
# in allo, i'm anker tholls me becordan shoulloug
# ----- diversity: 1.2
# ----- Generating with seed: " knew?
# (i never knew i) who would've kno"
#  knew?
# (i never knew i) who would've knownis denneds deck remedsbapim)
# i'm thit miling moun' aell?y caniig you-devele thps werb guss
# an mrdy thas with the ccopsi’t say amd
# and wrumingebcorc??
# bovy nimgsritty ain't tre beem pproot ups
# it's tourd the ean
# i’m wor drave you your silued wan kin?p, was whed sucks
# workmunt's walk up (i'm rickin' beorel aloud angirtern't so treroun er, everolo on hill of a msoull mist the mermachs your here, yo
# Epoch 6/60
# 22610/22610 [==============================] - 24s 1ms/step - loss: 1.4232
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "hy i
# got out of bed at all
# the morning r"
# hy i
# got out of bed at all
# the morning reen call me the beck whote me the beck whote me the beck whote me whe fuck and i don't make me stand up
# please slim shady, way and just back
# i'm back
# (i'm back
# (i'm back
# (i'm back
# (i'm back
# (i'm back
# (i'm back
# (i'm back
# (i'm back
# that's just bay man, the real slack why you want me the me to little back me blease slim shady, when don't wanna funkens and i don't wanna fun you say i am
# if i wonna to
# ----- diversity: 0.5
# ----- Generating with seed: "hy i
# got out of bed at all
# the morning r"
# hy i
# got out of bed at all
# the morning reing like am, it, but you don't truen me who dead
# i don't gon't wanna just like my take shit, years
# and i wanna to lot crike and who you con't say and wan dren am
# i just here wring, she me
# it's back
# (i'm back)
# i'm back
# (i'm back
# (ham, you wanna fungo don't wanna fun you'se want and it oggound and i'm a crimin'lle
# so bug in
# i'm stick a crimin'l and i can you can the ain't wanna ren and the real sli
# ----- diversity: 1.0
# ----- Generating with seed: "hy i
# got out of bed at all
# the morning r"
# hy i
# got out of bed at all
# the morning ronced on the ronamal
# and weile, suck you thong no me that shady'-s orf!'s
# a neve ffom in anowners in they fack-book you just worle!
# slit it's back blyy chaan, i just alratal you
# be i gootare-is smimt up tho olbretters hese and at
# i say i sayd yajl hake in
# si pus
# peent
# bay lad!
# get tod up cluw youre
# frach me the ne, the pabra
# be she at
# tratte lafe think us ware-ed, just fingorda(but ppentonters dou
# ----- diversity: 1.2
# ----- Generating with seed: "hy i
# got out of bed at all
# the morning r"
# hy i
# got out of bed at all
# the morning row you srom hyll)
# i'm back)
# "crchuwc, suck getinwathe, you you just wam)
# ha'i allieveran't proback me
# byacachess call't muke
# i'm arcid!
# and fillas
# tue of sccapy byon's i'm unke, (usi)
# 'caust act
# imjs dewnno
# yck, havedwrong no busies
# 3oever of the bluck whery it out
# i got of yourub um
# noed ie
# don't maril
# and wath over floc fucky aroun it's nor i talk! my ten that
# why of loted 'em blyce
# every, get s
# Epoch 7/60
# 22610/22610 [==============================] - 28s 1ms/step - loss: 1.3037
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "l you! you don't want to fuck with me
# gi"
# l you! you don't want to fuck with me
# ginta fuck a crazy that i wrong in the neating in these druss a cridinal i seck is the peen you do stand up, please stand up, did is his drim shady i trunk and play me the real shady is and just said a drust this whit? don't don't don't danna fuck as from amityville (he'll)
# accidin'm the will the moning these drugs rem make that shit drim shady dousd want dound i that this why what i way a don the f
# ----- diversity: 0.5
# ----- Generating with seed: "l you! you don't want to fuck with me
# gi"
# l you! you don't want to fuck with me
# ginta hall me shit, i'm a cramin' and you at man, you stall this with me are a croppin' the pust me the real shady all you villin' you faid if you don't don't dannil and the mos is of your pitchin' the fuck is how did with me want it the nall me the well at the real shady wonga the will they sand you don't think it a des your pit the pits in up in the mother lut a duck me snut a did and mars and a t
# ----- diversity: 1.0
# ----- Generating with seed: "l you! you don't want to fuck with me
# gi"
# l you! you don't want to fuck with me
# girl us and fack me do stn't have an you don't wanna go dam)
# ald shady, just don't wanna de, i drabs lime and pst and it whe to dougg!
# ('em the "roway i just? dain'llsfnawhop all throuse show ail thered dick is without these druss big, this just cam, thesechedd to sue it the night suck you don't galle am?
# her gonathed (whrem what-thilbs what fee the on the mast man ind cho, on a hove every dim shady
# ----- diversity: 1.2
# ----- Generating with seed: "l you! you don't want to fuck with me
# gi"
# l you! you don't want to fuck with me
# gint make withot yeallr an theer suting" i car men i doed on theshodrs, fitits with ma lial (hy rest me sigst dud hi
# i'm you live with tho! it, kim! is that whot?e't .usi the pacledsohutn lifuing driestust, i a resparies at me drim, doms woouce songo you ms shit? lottme mother blacd, they auds, knew)ibe? wosh you penobl, i just, becridcdbdo, me us this pit you in he will i mriget snit, throw dus
# wh
# Epoch 8/60
# 22610/22610 [==============================] - 30s 1ms/step - loss: 1.2028
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "rshall!
# hey, remember the time we went t"
# rshall!
# hey, remember the time we went to min't like me want dound it out the mather all of your hat the mather all the mather all you lotting
# so won't the real slim shady i tanna, where you can't see at all
# i just say that way all you want me
# you call me shit
# that when it's ancert the this with a got a lot his will me slim shady slim shady slart all me stand up?
# 'cause i take standin' mather all the back these drugs really got a got a
# ----- diversity: 0.5
# ----- Generating with seed: "rshall!
# hey, remember the time we went t"
# rshall!
# hey, remember the time we went to little little to be be a re
# oy the real shaty, way just let me latel what chat villin' mothere songed and it all
# it the bit
# dun the really wanna fand waited for i way a toot
# wath on my all you!
# for fay, i don't really got a lough me crachin
# look, where you here the be't the way the fuck of your to that i bont you
# good him to mule
# 'cause they bullers
# all i wanna got you don't got the a way drince
# ----- diversity: 1.0
# ----- Generating with seed: "rshall!
# hey, remember the time we went t"
# rshall!
# hey, remember the time we went to being woth it, sheeps, with a man get? whor's just this pikes let it? incerse. dodn't, cancerse
# you can't all ot lookey ald so thet harked of world, men'taughtit
# don't got this upais corn
# to it my he's? here you famior, hy dust back
# agjusters in
# these with uper than froom allut it
# been say dids it that you, hat, hy way affuggea nothen
# my taswabs
# that wattaeg
# i'm robping that the othat way my hat
# ----- diversity: 1.2
# ----- Generating with seed: "rshall!
# hey, remember the time we went t"
# rshall!
# hey, remember the time we went this lolies got a bad no littlare, laredangac-)
# an’t shit that you lainnay, flapin', haddree mercied man, do woll up dawn
# all the fuck et him a pusiugo?
# don't i froblyence
# to osher to x nith
# whaneffibs ay and love a a-at
# it's sorgmare you fartyat
# shit, shitmers
# aly give atent, illy, "y bleinger they, with a fay
# i ampio the wanna litch's want-with har
# and lake a nixt(y'ss,
# whotoy't you like really s
# Epoch 9/60
# 22610/22610 [==============================] - 27s 1ms/step - loss: 1.1223
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "was high when i wrote this, so suck my d"
# was high when i wrote this, so suck my dick!
# i'm that sting to be be the that this so gue stapin' to trunk it see
# por you worlound to sell
# and i don't want me to that i somestit this with this somess i don't say i say i sain'the realin' on the balls some on these do goter to been it all
# all they slim shady slim shady dallim, so drust this some on the fuckin' i got think it all it allies if your pitture this some sompor they say that whe
# ----- diversity: 0.5
# ----- Generating with seed: "was high when i wrote this, so suck my d"
# was high when i wrote this, so suck my dick!
# i never knew i dound to tall remalled for pitter to me
# that's why they back of the ainat to let me to that shit like stirk
# i heve you get the fuckin' that i would i pay i say i am?
# in the pape the aidit serit
# i am that's shy'ed up
# please stall ot teren they kids back
# shey shit dews
# what i've bace
# so that shit to truse
# so wrongs to don't gote me outta gatta gat this is his didetsed it, i'm anc
# ----- diversity: 1.0
# ----- Generating with seed: "was high when i wrote this, so suck my d"
# was high when i wrote this, so suck my dien!
# i came me
# in the raming
# like to beck
# sems ofth fegues out oo the bithout foungefeforemitherss singid to dometitedeathing some shat i hall your some sad me from ampporbons
# to the e’t niget song this world to but like mal, eesting of y, eright up to dound too it, renting, bitches and his twe fuckin' to weld of the rams, haddain't his
# i seeling whilestesfshall from in this world
# to trow ele
# dide
# ----- diversity: 1.2
# ----- Generating with seed: "was high when i wrote this, so suck my d"
# was high when i wrote this, so suck my deck!
# slle, say acfuck mat'rag tiugoth, hey, i'm driginad how it
# somelitch is me
# they last the little lige of me
# 'cal me cluses goy someshes, and kend it a kwo jakr
# aghy other songou, eight him?
# i’me the wraced to to do you!
# you can haioun
# i say i am
# if thinked th you atter iteng!
# skim sord be from it's a suckin' of hese wholls i can ruesil anjs!f’s leal me gue!s about shit agged
# and just kike stra
# Epoch 10/60
# 22610/22610 [==============================] - 26s 1ms/step - loss: 1.0527
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "in a tub but that's normal ain't it norm"
# in a tub but that's normal ain't it norminger, in the ball of your hald and to slut i shing i don't want get his his press it all me slim shady, i'm just slim shady, yes what? they's)
# get the blad, you can't bug i just samithes
# like me shotta tall
# nees, gud, who been i just sai when i don't got the ball that i whon't dentally got a hold of me
# 'cause they's)
# get me guess this why what i'm just slim shady, yes what i'm just that you can't
# ----- diversity: 0.5
# ----- Generating with seed: "in a tub but that's normal ain't it norm"
# in a tub but that's normal ain't it normoply wanna to sen all
# i call of yeah, i just sake shot it sing, with a goouthers without for the more
# they's hight, i don't want me the back that shit' and lake me to seet you tringt he lull me bitch, i suntever what i see plack allurem that the back that brigge, what i woole they say when i got you wool
#
# i whot don't i was go but you that shittoug
# 'cause they's)
# gettake must mith his year
# i just
# ----- diversity: 1.0
# ----- Generating with seed: "in a tub but that's normal ain't it norm"
# in a tub but that's normal ain't it normally got, centerened
# trink it, you been cults get him, piflit miny that i brongs him
# shady please stand me? dum! ub! juout like omm mibetsbend? flom i just amwind
# just maluu, they snat, when i ploug, wher i hear just told to we at
# i never knew i'd bat
# i'ma back
# that bow get, you'lh put ma, chatn en itgoy in huobs where i lette clus
# i sus rut see babt lake i wrobe of upphess i'm wisken't hear stap
# ----- diversity: 1.2
# ----- Generating with seed: "in a tub but that's normal ain't it norm"
# in a tub but that's normal ain't it normnalfith what
# you came this gast aghxdres
#
# an-yake, chenke firive'swanc!, yechin', i'm sr manach
# that's why when i'ds
# ach i for a troot (it crami, livep drobm ay these whold up the last bably this kiddin' i go kin't like this blistsespisugo!? do slut vulfs 10ing
# shey' graves sif i just was wind with a kndyvin', sweet to say i wanna canout my direts haal)
# i mate me alk in youm make this bedor!
# my?
#
# Epoch 11/60
# 22610/22610 [==============================] - 25s 1ms/step - loss: 0.9928
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "chard pryor
# (aren't you a male dancer?) "
# chard pryor
# (aren't you a male dancer?) me?
# i'm a criminal!
# i'm an inder to sen a hing to me
# back, they and up in the mother trank and make a hed and the motherfuck with this with the mean you sen't and up it the back dring it all me so when i was diess here, with a fand i am
# walling shim, i'm a criminal!
# i'm shady, you can't and up me so now wo lated to me
#
# i'm a somethe more
# the bably night be the moch me somether albuble maning don't
# ----- diversity: 0.5
# ----- Generating with seed: "chard pryor
# (aren't you a male dancer?) "
# chard pryor
# (aren't you a male dancer?) me somether and my min this way why wo le mech me the michere, it's a criminal!
# i'm an if himin'
# so won't think here, ean, you're so prong ron a could't not a manna the mothers to me
# the fuss a morh
# you can he mather all wall be the moch me stand up
# please stand up
# please stand up, please stand up
# please stand up
# please stand up
# please stand up, please stand up
# please stand up
# please stand up
# plea
# ----- diversity: 1.0
# ----- Generating with seed: "chard pryor
# (aren't you a male dancer?) "
# chard pryor
# (aren't you a male dancer?) is har-, deanck, i'm a criminal?
# to the cver upse
# faine, these choppst head ablavely mist me (widd'e shotdreal to say when i just did me she pal(sting porecossenn
#
# the the came at chilifainald and mike up but hoods
# it gone it drim slim shady, i dress me sadd ush man, my deend micah't stand mey blare ag llave mowher, i'm rine-, fon you
# peated broriend? thpt sin't at make me thinkef of aging dome to
# ----- diversity: 1.2
# ----- Generating with seed: "chard pryor
# (aren't you a male dancer?) "
# chard pryor
# (aren't you a male dancer?) pistoredens
# just somenobed wath that's just sebowest yeak!
# guessidem?"sminille
# no, fon every hisille get on you
# fuckin' this is was di bit?
# and if hey iim-hig -where recrew the pprobe slum
# hy minds down' snoppbroo!
# me)
# betim's keck, ever or whete itgay wanged, i jusk thit (th-skn’ce, i just asbwaing is hese abrot-as wingare you ase!
# i'm jrome me to hills
# and i'm tillin' it yor hanbl moore, hick m
# Epoch 12/60
# 22610/22610 [==============================] - 22s 986us/step - loss: 0.94380s - loss
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "fuck, spillin' guts to you
# we just met, "
# fuck, spillin' guts to you
# we just met, beck, then but no, i don't got a lough, wath a got to all
# and it it the beck, what i want just did i been you can't been at all
# i want hit rucking the corence
# you don't give a fuck, with me gudn me it all
# and i the never the fight stink
# i'm some shim than they call me so wrenk die worldand and the corunkens and the corurders and strot me the real slim shady wand up, please stand up, please stand u
# ----- diversity: 0.5
# ----- Generating with seed: "fuck, spillin' guts to you
# we just met, "
# fuck, spillin' guts to you
# we just met, beck)y
# wan a dinty all you lope a crape at the sers and just at bitch
# i'm stazy i take stack
# they ary get barked like it out me
# on a henniblay i just like you wanna get at all
# i was day it hese dright woulda be goed and the coren coures a crapren
# the eenbed to the call me (ther?! do!
# 'cause shit the real slim shady want like i got a loot, with be gon't, bitch i sead this will got nimga the real sh
# ----- diversity: 1.0
# ----- Generating with seed: "fuck, spillin' guts to you
# we just met, "
# fuck, spillin' guts to you
# we just met, i'm slim shady, yer wnothin', nexther offromtwhere coupecncotying like frim than wo lew 'tr?
# and the core will up "all you he niwh amapat yours ass ash the morders
# (i'm back!)
# i'm back
# that gvey night been want
# my fife this boyd not bit his wirk alboot me the?r preatin' thoubn bitch, "hald you whot a lots 'em wanna, get as please motherfuckin’, pastyoun a crapber ic
# i do to tre will be this will m
# ----- diversity: 1.2
# ----- Generating with seed: "fuck, spillin' guts to you
# we just met, "
# fuck, spillin' guts to you
# we just met, yeal! up in the bordied and he, just make up
# please shat that shit
# on the stras
# hesed and trape
# reepo seen it  aioin, kin't, that's figute this eake that me
# and to meats all to someme
# i'm a knoch triik oft and to me
# back, my winewiedt, just thoed of yours look with miss like i drath you senge
# but they ainn't really not piegs
# bewond wharpeestered winnaingwon’s you as the child, the, andauendered co
# Epoch 13/60
# 22610/22610 [==============================] - 24s 1ms/step - loss: 0.9015
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "s get so squinted, i'm blind
# from smokin"
# s get so squinted, i'm blind
# from smokin' her wallor with the be me out me
# the a way when i don't sextholl you family still they way i just dough up like it out me
# the a way when i don't day i am
# i ally i seen the peoll stand up
# please stand up, that i way this shit me the ween me the way i tring the beed was calritese my gade a could of your like a fuck it a figgl no got the beed wan sun chere just lille mat, stand up
# please stand up,
# ----- diversity: 0.5
# ----- Generating with seed: "s get so squinted, i'm blind
# from smokin"
# s get so squinted, i'm blind
# from smokin' he won't me to been want funks
# it's not so bad
# i just, my dick!, he won't me man, it's day i am
# i'm a kill no sexpor when i dring stall
# they say the fuckin' had i stand a dull me
# the picked to sell
# what's the carst a homoun
# and i don't deal
# i just lillle me beaces
# and but i amnigh mand with his persing that i worle to me
# better then back getthe fuck of your fanged to sen a hold of me
# 'cause i ju
# ----- diversity: 1.0
# ----- Generating with seed: "s get so squinted, i'm blind
# from smokin"
# s get so squinted, i'm blind
# from smokin' her
# i'm framin'
# fuck you caure, doe sexprost, buy hanged breake (he's)
# "baty!
# ghat you he fom came she bitch in the mist me bitch
# you a dwas?
# what if yeal! it so how viol peery
# and a figgond up ow the letter suck ee, sien my retive years
# i'm a cramin'll me to dustle fuck you fangoed up in the mough
# douse me to see was bleedembally gote me she lot this mough-him, bitch? (you let moullid men a hel
# ----- diversity: 1.2
# ----- Generating with seed: "s get so squinted, i'm blind
# from smokin"
# s get so squinted, i'm blind
# from smoking thes coupin' life in men mucltstis shit with letry and be the weed up here, walnother
# you he wan ass every will from smuldmy all buck me went, no get ein, te
# remm brexde ever putrt at hchid
# lyod some-years
# and egen i'm halling the beas thina here's wish herousen)
# i'm a sionst, get i see nowhe haind herien't gots agaux?
# ha'e whe eet, i'm wish up, chre outy is me to really flim my shattit
# chor off
# Epoch 14/60
# 22610/22610 [==============================] - 25s 1ms/step - loss: 0.8710
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "r's throat
# guess who slim shady just sig"
# r's throat
# guess who slim shady just sighat me to like you car him, that y'all for sig ther arely got a hold of my say what's just to suck, you manna to bef
# i'm slim shady, yes i'm thanks and i don't don't give me alous of your on to somethes and his or these fired with a got it a gottambon, you son't got this world without me
# and i worl on a got to be be me
# bad him?
# i'm slim shady, yes i'm the real shady, you did mat think you can't sl
# ----- diversity: 0.5
# ----- Generating with seed: "r's throat
# guess who slim shady just sig"
# r's throat
# guess who slim shady just sigged with a car
# and a till they say my didd that y'all
# no to to the motien it you call a cooped these choppin' of my (ha's, you don't manders go, i'm kinis just lake me alotelle this word in the bitch, knew i'd get him to slit this (i'm was that i the big, you don't min't back, these fiten in the shottin
# ! (was how rem givlter to ducked and knew i'd get him to slit vis up
# i don't want agonowhin' to
# ----- diversity: 1.0
# ----- Generating with seed: "r's throat
# guess who slim shady just sig"
# r's throat
# guess who slim shady just siggh a blloght, don't sif wat hall mathard brother toin' of sugut!
# these drugs dead!)
# and i'm scain' up, what you, ginnd now bough sever and get at amowart boy crininill
# do i say these crimin' me
# you go sak
# an and and he will me nom slim shadys ere you did villy bitch! (trak!)
# and when's and wring the laughin' the backs this whisk i'm atcramen' the rining just like me alit that y'all if i can't say
# ----- diversity: 1.2
# ----- Generating with seed: "r's throat
# guess who slim shady just sig"
# r's throat
# guess who slim shady just sigh nigst on the bubsed
# tith ever sinem alarin youn tibl stiel it remict twit t of, fired i'm gon't douge this ass
# me they 'emisse
# you known this kill your lighs arecouin me
# you liftin', the eve, betcher
# you do now goo, i'm deckingerhed with the bitch! clikn sningod you as
# want befrote let beith me wis 'slust me and ht
# wo reave
# so whet (hai, you get somecolestileforem thee somebonts up me? is that y
# Epoch 15/60
# 22610/22610 [==============================] - 26s 1ms/step - loss: 0.8391
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "r me? slam! slam!
# remember me? nigga, ba"
# r me? slam! slam!
# remember me? nigga, back, the and want to dow's some to trunk
# and i can't see athall on your hamnat about me
# and i can't see pack ass leaved baby gete shoulda come beffore
# i was shot it your ham, you sengo, i and they alwing to sen at alre
# and who do some off the read slim shady slimpshadys are just this bent they say that shit ver wear and drapse and mann
# it's sound her and him?
# i'm so you don't like my shit
# that's th
# ----- diversity: 0.5
# ----- Generating with seed: "r me? slam! slam!
# remember me? nigga, ba"
# r me? slam! slam!
# remember me? nigga, backin' to lot i seel, i go gong i'm gongay i can i may i was i am
# i'm the realin' on you around sturd and a terugh around clim shady dluns
# all
# shey's you can't see what's tound wher what's come some one offf
# i way that's keen me that's now what i'm dender toress and a night? that bord be the and want and just this wonth
# the weal, i with a coudd down to say this with a couse and knew i'd atcord to t
# ----- diversity: 1.0
# ----- Generating with seed: "r me? slam! slam!
# remember me? nigga, ba"
# r me? slam! slam!
# remember me? nigga, bag
# i cas a lotie my saim i the callin' imm and get that thes abes
# me
# that you a bit me tras
# i am
# i'm a cripinn thious hist in the sedis out as liken low go, loted aid would, i got oxt sont?
# 'cause i way a got voood 'em ge-us outtake, think anstes is you
# don't llave my sack
# (i here so sic man wo'd i'm leady natin', chart geap ats are just his
# what up pleasens, had and off (i didn't so it aggot your
# ----- diversity: 1.2
# ----- Generating with seed: "r me? slam! slam!
# remember me? nigga, ba"
# r me? slam! slam!
# remember me? nigga, bask my dick!
# 'cause these ghin, you're reatied hirl on you
# think, re. lam abpbow no bes
# he, i gasi't shit violyes of the rosticed this with a haxwher who dougs
# and my had and hin
# some sock with that i carck, i'm get" in the carcorsen'
# they sin't nigga, what-'male stand you
# remumbal songs ass
# cam! aftive up beck, fours's actusever i was a orties
# wealin' a way towo's like comownin' standin'
# that's to
# Epoch 16/60
# 22610/22610 [==============================] - 26s 1ms/step - loss: 0.8123
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "ble for your actions
# upon purchasing thi"
# ble for your actions
# upon purchasing this world with a god's lotterfuckin' i'm a criminal, the motin' i'm a criminal, the mot me to sleem and ple some to trunk
# i'm a knime the mothere dright to selle me, what i'm a cramin' him to slit the ralle shit
# and i a stap
# this wonts get his his is me to the fuck way, you'll fuckin' here you ass where and shit the press leat me sho't no see a don't got a loughare in the press like shit stuck up on
# ----- diversity: 0.5
# ----- Generating with seed: "ble for your actions
# upon purchasing thi"
# ble for your actions
# upon purchasing this fuck of the neating preatin' of yeah-hade my gade hered and helf ass me the neatin' when you ass wwith the callesters whole you get stop callent, you did me so why, you want every night be i'm a crame! well at the neat so like it ofrout
# i never knew i)
# i'm a knime no mean i don't sio bitch is stack
# they hat, the fuck you can't pleesend brosmers whole houghang where, you wath a cound yell staps
# a
# ----- diversity: 1.0
# ----- Generating with seed: "ble for your actions
# upon purchasing thi"
# ble for your actions
# upon purchasing thisk and walk or the a wanth mound machis, i thusne, then bact, bedonered, i doze me to slletted agd fack of youse a hope?
# aching and for isever hom
# what when and get the pittle the pips, whord nos fromt houl!
# nobout with up at?
# and shoutin' it the big this ming no beed, so wye, "i hadve, wher you get mothersuact git, 'ell a crimed!
# now fuld of the nause they corloube, like it? hes what? the balbsin
# ----- diversity: 1.2
# ----- Generating with seed: "ble for your actions
# upon purchasing thi"
# ble for your actions
# upon purchasing this fick?
# you fuckin' he wond?f i'ms dodrochto miod bitches asswyes, "i cropsin to you got stink a bul you doppy, get ow it
# and i wanna to sluz
# in the lrst
# and shey i hese a night cared you wanna to sonk woulda bedy wanna domn raie dop
# in your? do shitto can't just pleess
# calli't no vanivaning lif!
# i'm start you to bey with your stand
# i'ms frimnas you (i'm jukfiall
# aming my god?
# it, knew? yey gon' u
# Epoch 17/60
# 22610/22610 [==============================] - ETA: 0s - loss: 0.790 - 26s 1ms/step - loss: 0.7910
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "th dead
# and you slash your own throat
# so"
# th dead
# and you slash your own throat
# so i don't want and with a got with this wing was his his his his his his his his his press who really flum about me
# (i'm she't you really wanna fun the bitch
# i never knew i just do blong in you
# can't wait get but i beed what i way think i'm realith me (i'm like a like me stand
# and shitch it three to say these cragss or the ridien and shouty who sall me when i just die sickin' and from aminn!
# i said
# ----- diversity: 0.5
# ----- Generating with seed: "th dead
# and you slash your own throat
# so"
# th dead
# and you slash your own throat
# so i swattare on me
# 'cause you think i'm livel an and him is you think i me and i trunk ass homm and like i stat
# we wirl that wrow i been i sinever i wontad and dien it out me
# and i can't seall you
# , don't want and make the right what i worle these coured of your sig
# with a swatted and punt to see me
# these shottreath the and punstle on my catching or man, it's a cramind
# i never knew i, knew i just d
# ----- diversity: 1.0
# ----- Generating with seed: "th dead
# and you slash your own throat
# so"
# th dead
# and you slash your own throat
# so now and on the modres
# knea i go ton to all
# i don't like from shim
# ha’by in the wyer th, cut you wer wain't hust clim shapim
# droppin' the pist come or littles
# i never wend it's sick?! rume from i onttlient, no beed flea is every nip to me
# and you mannely bitch, recanteis of you worle to as
# a?d flim these drugs
# i don't know why what i've knong in your sically just wath me ard
# rememban i pub on you
# ----- diversity: 1.2
# ----- Generating with seed: "th dead
# and you slash your own throat
# so"
# th dead
# and you slash your own throat
# so waing? nowbont sngoit me
# ald tres
# up of me
# 'cause the fuss lifess with u hrate at at all ouris here, ducked it rewad man
# high as gomothim tillent, bitch! i never knew i fuckin' slim shady, yes up hald back, the stcrown "th, didied and every p retime erste out it 'til deating out up on all
# for i 'singe byithveren where hit? this kich of your
# right wallw
# i'm grabhin’ arougo?
# remembinns eridevem, i
# Epoch 18/60
# 22610/22610 [==============================] - 30s 1ms/step - loss: 0.7727
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: " is me now, the recent dude who's being "
#  is me now, the recent dude who's being you wanna to song ass for the reasin' the back, they say that's the droust stand up
# please stand up, please stand up, please stand up
# please stand up, please stand up, please stand up, please stand up i'm drick
# of my teren you as thain i bon't got a love of your haming, with me
# only nigga ter back, the realin' of my than they slues
# is you said if you'd dead a songed to sell
# and you manna the bit,
# ----- diversity: 0.5
# ----- Generating with seed: " is me now, the recent dude who's being "
#  is me now, the recent dude who's being you shot my ganna, for this bitch, i drinn as like me out a hodnat a love
# i don't give a fuck, wath bitch was his wristin', bitch, you think i'm sonettin' i got the press in lye
# and i don't got that but it's not me
# the fuss about me
# they say that's the realin' of the night, little from aminow dow man this me?
# what's chrost life!
# i donith of mate a that it this wited not male
# and from a swashed up
#
# ----- diversity: 1.0
# ----- Generating with seed: " is me now, the recent dude who's being "
#  is me now, the recent dude who's being you think it to that ow gotes him, "
# mather all yourm!
# (wah, you cas twind for kid' yours for of everyore
# that's keed my sight was out ass
# in they coulh, bottyess
# mansed to screntidau, but i setter thrugkewnoff thin' it the rell you aingh to dusels out the mothers your to befting crool me!
# men they fued twrowelt corem whery and shotell exters duss cadpent to of aming it'll a could you?)
# i'm slim s
# ----- diversity: 1.2
# ----- Generating with seed: " is me now, the recent dude who's being "
#  is me now, the recent dude who's being your fagithorid frem antelficed ere!
# "he won't cappel stop pefboy elsith they hall
# me, what's life'tat whoulbu-gad? ass look betce plict
# that i got that but the man you to) and cas
# puringed
# fyrettimnso liggels out gua
# and ol just let me 'tm that i ghting of your hand for crep on, kim, "i wanna fuck year you think the indriddens let blighth?
# fum no muby clim mant
# my stappin' and my him is jesus fuc
# Epoch 19/60
# 22610/22610 [==============================] - 29s 1ms/step - loss: 0.7424
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ve it?
# i know you got my last two letter"
# ve it?
# i know you got my last two letters
# in your hall of the nees, and get was doube somess with the real slim shady, yes i'm the real shady
# all you do slim she's culd up to stand
# i can hall on they say wher i was out me
# 'cause i'm shadyn you can his his wink i can hese my gens ain't was 'cause and get a little somess so wrown i can is so ligga no gon't got the ralle this worsed gets age
# i wrough like the mother and get of you
# go i'm l
# ----- diversity: 0.5
# ----- Generating with seed: "ve it?
# i know you got my last two letter"
# ve it?
# i know you got my last two letters
# in as of off thin hy, cal, they say what i just said some some nomos if your ham, i don't make in shist about me the callim that i was in he like if i need to a had
# from in the singor this is at me
# and i never knew i'd get him to suck my dick!
# i'm some to said i need to me
# the poppin' the to standin' don't wanna go on
# but whot, no go go bad
# wan, you'll on you
# helf your singod fendess of your hou
# ----- diversity: 1.0
# ----- Generating with seed: "ve it?
# i know you got my last two letter"
# ve it?
# i know you got my last two letterss canco's life's a crepor oh tous
# what of i go was on go
# do shit
# s lit mat you hill get maugh of me
# no (gike a boot
# they's troot to sugs?
# who world him mombanc someress ared and mave i was got it out melone the lottin' his hoarwnimes
# ald i the viller drew, didn't i call peat that you
# so lo got, but i beed (fostever
# you i've beld your a sif you, it wer wood me to loak it, he wend to ming me to yea
# ----- diversity: 1.2
# ----- Generating with seed: "ve it?
# i know you got my last two letter"
# ve it?
# i know you got my last two letters
# icker whot just goin' to's as a'mluc
# all bly wanna recold the cos, nexther furst was dound my say you
# sping, you did me so supson fay i’m tirdin' hil! i go wound updo hell of has
# they say i tayn' fand so lotting out hyor match, leater think a coming sick is, your hould of the never kneam of this juss
# end to do
# i ampid about you
# hould you!
# 'cause they bull verss ags
# ass
# , ppe't?
# plo, i don't i al
# Epoch 20/60
# 22610/22610 [==============================] - 25s 1ms/step - loss: 0.7211
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: " by the way, n'sync, why do they sing?
# a"
#  by the way, n'sync, why do they sing?
# and if you do to trunk it me to see me alout with me and slim shady sut in the back drink it been in the baby on these courd back dreat me some of your bitch is so i was od to sell
# ay all
# my he's druck really got a hold of me
# 'cause they and but ne, keepin a to to that it
# i'm rond that i the pittle sholl of yours
# and i don't want and to man this wont ass
# little lasted to that in yess who just die s
# ----- diversity: 0.5
# ----- Generating with seed: " by the way, n'sync, why do they sing?
# a"
#  by the way, n'sync, why do they sing?
# and trown't who i'm gons to love me slim, shese drugs, sand i dress like shis with this slis gots they suspedinger dunstawant floups last this bitch
# i never knew i) me to diens slie shady, wing you do it rewad it every on to lit, slupps expense fires
# i cope this wont ass list me back? so bughin' now, deed me to that this world in the fuckin' it to be be meme)
# it's back, threed trope back broughed a
# ----- diversity: 1.0
# ----- Generating with seed: " by the way, n'sync, why do they sing?
# a"
#  by the way, n'sync, why do they sing?
# all who hear of her and here
# drown, slim shady sleapje and just tip od do bit?
# you kell the knew i won't reaped some
# that it me bulb
# they fir this bronged bitch is you'd don't mansed
# and age drim, in ut, huy (i'm?
# he gunns, so i hoory twat, you
# wever your fom like a rucking her?
# hate the wrownin' frobaby could stapin' wherey and callont, let it virliel up, the ain't get thinkin' i'm pricnna
# thered
# ----- diversity: 1.2
# ----- Generating with seed: " by the way, n'sync, why do they sing?
# a"
#  by the way, n'sync, why do they sing?
# and tomed off of hese
# and sho
# they as cill her put 'ell get lattlees, suthin'
# 'cause in the knear my rewringafferout asowhen then think you won't tas
# what-vido of you
# gued of litel hit diess give as lost my didred
# 'cause fath with up?
# you llove sex his will it sec doin' ofrent smind i never knew is keeps seapriend love and suck cridy up on trody no, sulpstin' frobrybe from and whoro?
# they fuckens t
# Epoch 21/60
# 22610/22610 [==============================] - 27s 1ms/step - loss: 0.6984
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "itch i'm a kill you! you don't want to f"
# itch i'm a kill you! you don't want to fuck was dien drunk with me
# gon't not to lore it, you think i'm so ithor litel bitch
# i never knew i) man, shit you leave me wrode
# i woolo night if youed man, i'm remem in me, what, i don't want and just die shit? remum in and mane me (him?
# hah,,, you head i am
# i am wold in the proplem and she will or wasted to sell
# and i man this is right whord pight of me the a bitch
# i never knew i) man, shit you
# ----- diversity: 0.5
# ----- Generating with seed: "itch i'm a kill you! you don't want to f"
# itch i'm a kill you! you don't want to fuck way, your low you don't, i med me something these dien is so bitch
# i'm back
# bitch i capse the a be that i wrote this blotelboy it
# and i never knew i) montare
# these’stollictin' ome
# on the ball on it
# as had
# and if i never knew i) son't not me to see me
# 'cause i'm a criminal, like a fuck, we didn't i got the ball you can't he pust the a lots me the a write it all the stret up that i the mathers a
# ----- diversity: 1.0
# ----- Generating with seed: "itch i'm a kill you! you don't want to f"
# itch i'm a kill you! you don't want to fon slim, i'm aicragh it
# i seen i pay in yeselfichstrist goin's offrel a tever speest like a dusting reiplent like, who wos bitch is of your hat
# and iff of this is rochicns, my thien in yeahele
# 'caure where the pitckin' how, punsele
# these fitht the back nod the fuck ue! i never knew i'd and mans rike a fun these lost me? bithh if if s i mean drid i’m pince, this motherfucker thinks?
# yeah, you healf
# ----- diversity: 1.2
# ----- Generating with seed: "itch i'm a kill you! you don't want to f"
# itch i'm a kill you! you don't want to famill be moched, wher, i dod was cas, i me, chew and ple so live iflubure
# so bin vrobass slue i just jake and stand up, i hate meftare the pust make a to got the ball be the aistust mat-lire
# liagh, he's or he’ly didn't haa-waice did)
# i’m just a roid was fee i som thoour
# and had on looks
# about ug
# i'd and peoper to a leave me?
# what whove you
# don't slum if erout mil!
# chew in the atit twound slis gote
# Epoch 22/60
# 22610/22610 [==============================] - 32s 1ms/step - loss: 0.7038
#
# ...
# these drugs reall fom me? mer me! i'm rond of the fits cad of expter, years
# i fon a coopor a bunch
# what ving ringad? cound just make in ’mating whode to expor these
# if you be’
# Epoch 54/60
# 22610/22610 [==============================] - 39s 2ms/step - loss: 0.3857
#
# ----- Generating text after Epoch: 53
# ----- diversity: 0.2
# ----- Generating with seed: "nds
# bizarre kid, swifty mcvay, the kon a"
# nds
# bizarre kid, swifty mcvay, the kon ardas of the corresting
# sleapsi' that i way i just tall
# i came and pub on your
# on a don't at all you'round his shit
# so windo, some on your ancever your only her?
# you don't want get come on
# and then you come somen motherfucker give a fuck your family still
# think ay fin't a crash that what-ass
# he's a know it the stuck me shank and just let this bitch
# i never knew i'd get him to hit this bitch
# i never
# ----- diversity: 0.5
# ----- Generating with seed: "nds
# bizarre kid, swifty mcvay, the kon a"
# nds
# bizarre kid, swifty mcvay, the kon ardargurs
# ame? who sais roor me!
# but i say i am
# if he drunker, i'm rock
# want (he's funkstan bleen clim, said remoupins and put your pitthe latt out to our me
# mustim shady
# we dued me like a little ball you don't reall the trunk
# and tring of your on
# suck my dick if you!
# don't hall now, i'm dridens
# what's you caren look me wanna men and i his your life!
# astilleve mering who do be brist
# i'm some of you
# ----- diversity: 1.0
# ----- Generating with seed: "nds
# bizarre kid, swifty mcvay, the kon a"
# nds
# bizarre kid, swifty mcvay, the kon ardian i don't car in your son
# yo''ckncraby, you
# you'rer get or the mic and for figgorn it? your sing roop head scring
# wan to double the the malestain's und peop ent
# ce on you
# and i can't reapp, spit suckin' him?
# ham's gong i beed me
# he's knda back)
# dan't just beew bunkall remmmachin' the ton
# the work it! i'm a criminal
# and who love it me comp of beforem, alound shit
# like her with ther i lottleal w
# ----- diversity: 1.2
# ----- Generating with seed: "nds
# bizarre kid, swifty mcvay, the kon a"
# nds
# bizarre kid, swifty mcvay, the kon ardom
# dundrille nopope, let's bedy caes
# abous it aight somebersbexspeck you hatthing
# so winnd, some on are
# for fir chely, why i'm your ham-on
# boot your sing
# i'm aicured he woruuner, end him toprin'
# you kell ye-!
# that i the life i to tall
# me mild tor a bankeing awwish is at here you
# 'catin', back
# my new's you but get of go
# i'm a known't you woolures
# and i gon't did?
# and thay this finnit! trank cut '
# Epoch 55/60
# 22610/22610 [==============================] - 42s 2ms/step - loss: 0.3797
#
# ----- Generating text after Epoch: 54
# ----- diversity: 0.2
# ----- Generating with seed: "decided to show his face!
# i hope you've "
# decided to show his face!
# i hope you've helf, stand you man, repouse stand his shit varing stirld with the ball on she carter
# these fire i just say these though
# beryou brook
# we wain' the same they and pun you dodn't would i way i just do with a carders of as por of of is or or aminowo let it, and want don't i'm a criminal!
# 'cause that's fuck is fallin' i'm just a go is frim shady is me to sengin' chooldan the eath betce
# expe come heappr
# ----- diversity: 0.5
# ----- Generating with seed: "decided to show his face!
# i hope you've "
# decided to show his face!
# i hope you've helffffft the mowhat i was herencall ther hug
# 'til where and keep assech, i want bedor wantses hiss
# please said i don't got that be gots acte
# and if you bette fuck aigh i was swa chit's shotta neroused
# no sen this wo that beenible
# you get so trugh of yours
# one)
# me to see me to tell leal
# i'm a criminal!
# 'cause that's fuck with me godda gun shoulda cal, they saule come trod on, me
# and and off
# i'm so
# ----- diversity: 1.0
# ----- Generating with seed: "decided to show his face!
# i hope you've "
# decided to show his face!
# i hope you've holloy i men a hom?
# and i wanna go on
# wook is and brigged arew who shit that be goter than befocostes
# (t'el manin', fay i the to that i just shot, you lot, bitchese stanin' i'm a crimin'lousing to be me
# and uf one to bef
# if he's on somerick to sen my pippen it get you argody
# and every do fol my shies
# (i'm gon’t song and guy fuck we do's why?
# and sleave run you don't really wanni’s and fell figh th
# ----- diversity: 1.2
# ----- Generating with seed: "decided to show his face!
# i hope you've "
# decided to show his face!
# i hope you've )id'! (ajlu! (i'l) and and are from amityve latey slim shady
# (i'm waich doess life, i'm spamince some now i want, without smond up in up, bleese's? though, your )ame slim shady up?
# all you don't lete stire stiry the stand hey
# for poopred up
# him, the brock in the huctin', delly her???
# th, kids just hei’s and get but back
# and night that 'em wark (nom blase
# back meyech smatings?
# so bithor these fixl
# Epoch 56/60
# 22610/22610 [==============================] - 47s 2ms/step - loss: 0.3790: 4
#
# ----- Generating text after Epoch: 55
# ----- diversity: 0.2
# ----- Generating with seed: "m a kill you! you don't want to fuck wit"
# m a kill you! you don't want to fuck with me go
# a do the more, and with the real slim shady way dancle to deen you sentoop
# i and i came and caringe to tell me man, i can it, yeath agay me to sents
# and you call me the trum-
# you said i came and put your family stalle mats me shot a love mis and want bristed wreathin' he late's like a like me bull reall mather and put you wanna reat the ball the the mother leap and just make me shappy stur
# ----- diversity: 0.5
# ----- Generating with seed: "m a kill you! you don't want to fuck wit"
# m a kill you! you don't want to fuck with me go
# a'm? and buy you know i just do whore the mother in yess like i get bull me!
# ath when i way
# i cam, you get it, but in men you ain't puckin' and slim shady
# (bll
# i never knew what batched and ken coula, whoredalbound hing i don't villay i take she me, it's and and make in yess
# som that i'm a craps and trookin' me (he, want blon i scall me, whot aww while that this is me
# you go sentay'ch, you
# ----- diversity: 1.0
# ----- Generating with seed: "m a kill you! you don't want to fuck wit"
# m a kill you! you don't want to fuck with me go
# a'm? ain't haineare i carina, i love could way dun you ean't let me mite herouse thinkin' the knew i just troit bake me (fame rown aboustat got stream in atcrown
# and die wints to wath my casse's cartis wrote you
#
# now but the wallon
# about wink me to same withorure
# so won't carm anted at the ball of these chouth rmaw ro is it, ald a redew know when they bleedss this way i cashow could up hel
# ----- diversity: 1.2
# ----- Generating with seed: "m a kill you! you don't want to fuck wit"
# m a kill you! you don't want to fuck with milach
# and fuck bitch, yeal! (withouy you being
# , lot me kiddarentally jall you did i never knew i'd get him to sentoy thells off whinks ifremound fineor and broake
# reathstall from amityother and gueffum if alo's from amino, love my kithased me
# and i song , live come stress, fiffug me? my samily no-hha, w-old of of just die mrss, anout who sall me slits stoppy!n' the than the back dan't want
# i s
# Epoch 57/60
# 22610/22610 [==============================] - 41s 2ms/step - loss: 0.3764
#
# ----- Generating text after Epoch: 56
# ----- diversity: 0.2
# ----- Generating with seed: "riminal
# makin' a livin' off of the world"
# riminal
# makin' a livin' off of the world'e mother trapie (that shit
# me he duppen you wanna reat his ald the crew what a that i was shit a fig'te just lillinem, he like a like you a wasorwand fring shousc' an and real a cound und not a not a dound hill or the stre, citwne, what das
# i and i can how down and put you at that the ball the sentit to the real slim shady up ly prown't when alound hill remall slim shady up, stand up, knew i woul
# ----- diversity: 0.5
# ----- Generating with seed: "riminal
# makin' a livin' off of the world"
# riminal
# makin' a livin' off of the world'e mother gote me, so bed
# i just him to goin' of your hady you as too!
# i nee to do shit you
# and your stream i the real slim shady up, stand up me to drake and make me bust he be babss like i make a that you and thes firsilastions too a wash
# i aver me? slim shady up, dunt
# and trough when i don't get this big
# i never knew i would it'll a could you mutile to do it, bet in the car me that i been chrin
# ----- diversity: 1.0
# ----- Generating with seed: "riminal
# makin' a livin' off of the world"
# riminal
# makin' a livin' off of the world'e
# so mober cance
# i'm  back
# the back, that's thrs, way, and gun had me it he's leen you fuck you thrught? sten i was oky beer get if in the cardets getic lity i card
# and every pike this bitch
# and trord of jusudda
# no the record ups trober they drem and und plays
# i leve stre, din't why wall 'emigun a to you'll killiy preas ecting of is bitch
# to that you fol i withdohe fire i'm ajyiess hadin' to this
# ----- diversity: 1.2
# ----- Generating with seed: "riminal
# makin' a livin' off of the world"
# riminal
# makin' a livin' off of the worlda me of .ep to mother dape this?!
# by where the voiting ther hack my wanna fun you a wasownim the sai' heraw me, a hell
# me
# fame hah-hum? (ham!)
# whatver you shoutin' feros
# i cas swith a find of your stant up onl or the mncan'em to swant chack and just die sud it, yeah, is whot, you're just like me will a bunt keer act he?
# and if you growidna ton't in the, bitch, (you keich do or for make faces, hit?
# Epoch 58/60
# 22610/22610 [==============================] - 41s 2ms/step - loss: 0.3740
#
# ----- Generating text after Epoch: 57
# ----- diversity: 0.2
# ----- Generating with seed: "t a little baby boy
# my momma used to tel"
# t a little baby boy
# my momma used to tell me to leave me
# and the fires and play me are just his off this when and peopre yours
# about wird or reman shoudy plawin' up on
# lyome
# and they didn't be gots 'emrall that shit
# and i crazy shady up, me (trars
# that's know i louna now i could i trunk and drapse me
# and i that thie the crobsy mather that your man, ald the pornecting chopd stare
# so movir
# and i don't really dape thing off off the rem rem
# ----- diversity: 0.5
# ----- Generating with seed: "t a little baby boy
# my momma used to tel"
# t a little baby boy
# my momma used to tell me tlise
# hig to do of me
# 'cause when a guess who said got ow be more
# be whene standing withoring to sent
# you'd put your pifthat your sight being who is probaby, for pig, i'm goter plabed to that i go (nagust man, it's call x criminal, that's love it, i'm ruck
# aight who bedy say i tain't lake a fingo shouty!
# i hat that what whatha to do befrem and leave me
# and i ared a lifeve this shit wild on, m
# ----- diversity: 1.0
# ----- Generating with seed: "t a little baby boy
# my momma used to tel"
# t a little baby boy
# my momma used to tell mat, you
# so lown' goy the fusu to bexther it
# you beliver you wanna, i the bigge are dredy's dake me the trught?!
# (i'm a criminal, than i blee eders wigh if i con't sim somether knaw what i way i catchin'
# now you don't, back
# simm,, i'm son’t like this hay
# i never knew i, knew i'd a fathat
# ay these drown
# to tubke (i'll bedoug
# ashowant me you wanga get coube keew whote rears like me
# en maninally fa
# ----- diversity: 1.2
# ----- Generating with seed: "t a little baby boy
# my momma used to tel"
# t a little baby boy
# my momma used to tell me bitch it seus just like mms
# it's gouge-omedabode on let this write my ottare
# so i wintone to dodyour reine
# bitch, we evers or the trunk
# blew wher i have a jrom and may the law ya
# 'em war
# i'm swonting me to life! what or boutch babbs you
# raip on these coure crewss
# came of just diels
# i go tome shot shopin' downs down these didy sleepsback
# (i'm gon, this wonts tent to mibe fun leaver, yeah, you
# Epoch 59/60
# 22610/22610 [==============================] - 40s 2ms/step - loss: 0.3664
#
# ----- Generating text after Epoch: 58
# ----- diversity: 0.2
# ----- Generating with seed: "
# let me outta this place, i'm outta plac"
#
# let me outta this place, i'm outta plack in the nater shit? just like me was deen
# and i wo pusbout with hear stapin' the ball that who beck)
# you head i am whan i been climin' he won't just like me who mackin' the pait this wented a den't got finds
# and i a swing with hear saim shady, ye, deg't matelin' the ball that's man i seen you do this bitch
# i never knew i, knew i'd actumn
# and they do who back doy
# i don't wanna go on
# a little fuck
# ----- diversity: 0.5
# ----- Generating with seed: "
# let me outta this place, i'm outta plac"
#
# let me outta this place, i'm outta plack in the lape, that shere
# and i as if i cacks, dinne the mot the back in yess, let it out!
# and i was i say in amindem wanna gon a got mad, get on the mot yeare
# i'm a seapin' the back in the nater the mat 'em and want exthir
# and i can't see at a got me with the back in a figgor who man, no ber getwimen like a fuck it, back weve you get him to slit his wrist
# i never knew i'd get him to hit this bitc
# ----- diversity: 1.0
# ----- Generating with seed: "
# let me outta this place, i'm outta plac"
#
# let me outta this place, i'm outta plack in the later paby, where peanin' him?
# domn the holls
# and y'roph leat when i just die wroth men and shat of goy a of, i've been come on
# and i can't real a me the fackine who back wants just make!
# i'm slim shadyn't make sake saups (hit?
# wath me back
# they w'n his me the eat cause (i'm slim,, i just him wan, i car?
# akd a tend to must man, keew i'm dridin' the ball that's nowhouphy got now, but you g
# ----- diversity: 1.2
# ----- Generating with seed: "
# let me outta this place, i'm outta plac"
#
# let me outta this place, i'm outta plack graden, sent, i'lle on i doggamna fon a rad
# you?!
# i’m nimina, i som somet a live it
# demin'm record sta, i just take his his grasued a lottrough he won't? go ottar got a but of we tona
# i'm not pug?
# remald he busin a nome
# be if be come and maubly gad
# i leve slut bit's you stall me talk and please! i th, dead, you get him, afh!
# fuck i'm slim shady, i'm like-a fuck, sprem up on my lastider get with
# Epoch 60/60
# 22610/22610 [==============================] - 42s 2ms/step - loss: 0.3624
#
# ----- Generating text after Epoch: 59
# ----- diversity: 0.2
# ----- Generating with seed: "the numbers 62
# (at the tone, please say "
# the numbers 62
# (at the tone, please say your ofting
# but i'm stapin' the each it's just thris gets
# all it her kniting shit listle slim shady slues
# i'm a criminal!
# 'cause i don't got a lougas the cordens
# and i don't wanna go on
# living in the motin' men a hold of me
# 'cause i don't wanna go on
# will (he's)
# mentally ill from amityville
# and i won't just callann i just die hear some shoutin' prool me!
# be is outting to weed a cold of the fuck it
# ----- diversity: 0.5
# ----- Generating with seed: "the numbers 62
# (at the tone, please say "
# the numbers 62
# (at the tone, please say your ofther knew i was a love you wanna men and and trow what dann
# i never knew i, knew i'd ablive you
# me to sen you
# ald you me to sen a at we can deso sell, bas putrn
# less the reats like en be the wenpin' i'm pacilist met me, stick a tot
# i'm all stare stapiy dien it don't like a fuck dose let ghide
# and i won't just die how me slim mans
# and a resome to sen you
# and you call me slim shady diess acri
# ----- diversity: 1.0
# ----- Generating with seed: "the numbers 62
# (at the tone, please say "
# the numbers 62
# (at the tone, please say y'ram?
# remambed wrod in atten wher i was oul, get his his kind it top pubnec in leat liitelly nos is way bluck with me gring of my tend it, renoint all bary wanna the walkin' a pitioph cacky, the beot sexte shit that what fay i just clim some?
# who dun delle this night bas dean clitever is 'talin' the a won't you
# seen it, yeah, yourssed too
# slues
# i canni trawn bris us
# in the sow my with me and all
# ----- diversity: 1.2
# ----- Generating with seed: "the numbers 62
# (at the tone, please say "
# the numbers 62
# (at the tone, please say you prewiest swith me (finesil it slim shady
# slugpsed
# and this shit
# and if it suck, i'm drins
# if on the knew i who, w? mentally wath the balk in lace, bloy baby no gots like a fuck bitch come in her
# laul overyout me
# i wan thes snectupors)
# ne, kid i botollern't got twe hit
# and i canive mess me. connecticut
# out get dought tor like me to sallum
# ikduen you don't, back (for manch-ha, i walk that baby,
